# %% [markdown]
# <a href="https://colab.research.google.com/github/Wi-ll-i-am-9/projectzz/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-5b271ed6-a58e-4ed1-ae3a-697b4a628111" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b271ed6-a58e-4ed1-ae3a-697b4a628111">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
imdb=pd.read_csv("/content/IMDB Dataset.csv")
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A      142
# 1             The Godfather           1972           A      175
# 2           The Dark Knight           2008          UA      152
# 3    The Godfather: Part II           1974           A      202
# 4              12 Angry Men           1957           U       96
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    200 non-null    object
#  1   Series_Title   200 non-null    object
#  2   Released_Year  200 non-null    int64
#  3   Certificate    200 non-null    object
#  4   Runtime        200 non-null    int64
#  5   Genre          200 non-null    object
#  6   IMDB_Rating    200 non-null    float64
#  7   Overview       200 non-null    object
#  8   Director       200 non-null    object
#  9   Star1          200 non-null    object
#  10  Star2          200 non-null    object
#  11  Star3          200 non-null    object
#  12  Star4          200 non-null    object
#  13  No_of_Votes    200 non-null    int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 22.0+ KB

# %% [markdown]
# #Findings
# * There are no null values and there are object, int and float columns

# %%
imdb.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Director', 'Star1',
#        'Star2', 'Star3', 'Star4', 'No_of_Votes'],
#       dtype='object')

# %%
sns.distplot(imdb['Runtime'], kde = False)
plt.show()
# Out:
# /tmp/ipython-input-4116527666.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(imdb['Runtime'], kde = False)

# %%
sns.scatterplot(imdb)
# Out:
# <Axes: >

# %% [markdown]
# #Findings
# * The most movies were made in 2010-2020 era while the least in the 1920s
#
# * The most amount of movies have an IMDB rating of 8.2-8.23 while the least movies have a 9.2 rating
#
# * Most of the movies are 2h long while the least are 5h and also 45m
